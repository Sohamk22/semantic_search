# %% [markdown]
# # Lab 3 — Semantic Search
#
# Run this notebook top to bottom as you build out `embeddings.py` and `search.py` in this same folder. See `Lab3_Instructions.md` for what belongs in each step.
#
# This notebook is just a shell: it imports your functions and gives you a place to call them, but the corpus, example queries, and visualization are yours to write.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from search import (
    load_documents,
    build_embedding_matrix,
    search,
    plot_embeddings,
)
# Out:
# /Users/macbookpro/Downloads/semantic_search/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Step 1-2: Load your corpus and fetch embeddings

# %%
# TODO: load_documents("documents.json") and build_embedding_matrix(documents)
# Start in offline mode (the default) while you're building - switch to the real
# API once your pipeline works end to end.

documents = load_documents("documents.json")

print(f"Loaded {len(documents)} documents.")
documents[:3]
# Out:
# Loaded 26 documents.
# [{'topic': 'example',
#   'text': 'This is a placeholder document showing the expected shape: a topic label, a short text passage, and a unique id.',
#   'id': 0},
#  {'topic': 'example',
#   'text': 'Replace everything in this file with your own corpus - see Lab3_Instructions.md for what makes a good one.',
#   'id': 1},
#  {'topic': 'astronomy',
#   'text': 'A black hole has gravity so strong that even light cannot escape.',
#   'id': 1}]

# %%
embedding_matrix = build_embedding_matrix(documents)

print(embedding_matrix.shape)
# Out:
# Loaded embeddings from cache.
# (26, 1024)

# %% [markdown]
# ## Step 3: Run a few example search queries

# %%
# TODO: call search(query, embedding_matrix, documents, top_k=3) with at least two
# different queries and print the results
results = search(
    "planets and stars",
    embedding_matrix,
    documents,
    top_k=5
)

for result in results:
    print(result["topic"])
    print(result["text"])
    print(result["score"])
    print()
# Out:
# astronomy
# The Sun is the closest star to Earth.
# 0.34570126769963483
#
# astronomy
# Mars is often called the Red Planet because of its iron oxide surface.
# 0.29482067114464144
#
# astronomy
# A black hole has gravity so strong that even light cannot escape.
# 0.27167223441707106
#
# cooking
# Baking requires careful measurement of ingredients.
# 0.2716248766429844
#
# astronomy
# A light year is a unit of distance, not time.
# 0.26670314491983194

# %%
results = search(
    "python programming",
    embedding_matrix,
    documents,
    top_k=5
)

for result in results:
    print(result["topic"])
    print(result["text"])
    print(result["score"])
    print()
# Out:
# programming
# Python is a popular programming language used in artificial intelligence.
# 0.504532782710757
#
# programming
# Machine learning models are commonly built using Python libraries.
# 0.42481787697593537
#
# programming
# A function allows reusable blocks of code.
# 0.3898312098416333
#
# programming
# Git helps developers track changes in source code.
# 0.34243196711639196
#
# example
# Replace everything in this file with your own corpus - see Lab3_Instructions.md for what makes a good one.
# 0.3077582396348789

# %% [markdown]
# ## Step 4: Visualize the embedding space with PCA

# %%
import search

print(hasattr(search, "plot_embeddings"))

# checking if the plot_embeddings function is present and correct
# Out:
# True

# %%
# TODO: reuse your Lab 2 PCA-via-SVD function (extended to 2 components) to project
# the embedding matrix down to 2D, then scatter-plot it colored by topic
plot_embeddings(
    embedding_matrix,
    documents
)
